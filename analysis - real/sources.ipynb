# %% [markdown]
# # Books teaching basics of measure theory
#
# [Analysis, Measure, and Probability: A visual introduction](http://euclid.trentu.ca/pivato/Teaching/measure.pdf)
#
# [General Topology - Point Set Topology by Donald Timpson](https://www.youtube.com/playlist?list=PLJWhXkxQzDF79YNILTDtdtepY-nnfkKiT)
