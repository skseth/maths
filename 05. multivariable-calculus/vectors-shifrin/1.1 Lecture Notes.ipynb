# %% [markdown]
# ## Lecture 1: Basics of Vectors
#
# https://www.youtube.com/watch?v=8hX0QePiWlw&list=PL5I-Eyk8l9FHdJUd9UujGcvumjCFPHbrd&index=1
#
# - What is $R,R^2,R^3,R^n$
# - Vectors as column vectors
# - Adding vectors by adding coordinates
# - subtracting : adding the additive inverse
# - subtraction in terms of addition: u - v = x OR v + x = u i.e. what do i have to add to v to get u
# - 0 vector has components 0
# - scaling a vector
# - length of a vector - pythagorean theorem in R2, extends to 3 dimensions, then to n |v| = sqrt(square of coordinates)
# - 2 vectors are parallel if one is a scalar multiple of the other if v = cu for some scalar c, OR u = cv for some scalar c.
# - 0x = 0 - 0 vector is "parallel" to any vector x - the above definition (allowing either way) allows this usage of 0
# - |cv| = |c||v|
# - unit vector = 1/|v| v

# %% [markdown]
# ## Lecture 2: Application to High-School Geometry
#
# https://www.youtube.com/watch?v=uVG604svPM8&list=PL5I-Eyk8l9FHdJUd9UujGcvumjCFPHbrd&index=2&t=1768s
#
# **Show midpoints of diagonals of parallelogram intersect**
#
# - Given parallelogram OABC, O - origin. $\vec{OA} = \vec{x}, \vec{OC} = \vec{y}$
#
# - Let OD = 1/2 OB, E = OA + 1/2 AC
#
# Goal: Show D & E are same:
#
# OB = x + y. OD = 1/2(x + y)
#
# OE = x + 1/2 (y - x) = 1/2(x + y)
#
# i.e. the average of x and y.
#
# **Centroid (intersection of medians) as average of vectors of the vertices of a triangle ABC**
#
# $\vec{C} = \frac{1}{3}(\vec{A} + \vec{B} + \vec{C})$
#
# Even works if A = 0. Let B = x, C = y. Then centroid = 1/3 (x + y + 0)
#
# Basically given any origin O, we can write x = OB-OA, y = OC-OA
#
# Then 1/3(OA + OB + OC) = 1/3(OA + x + OA + y + OB) = 1/3(3OA + x + y) = OA + 1/3(x + y)
#
# Setting OA = 0 (If A is the origin), we get the required result.
#
#
# Where did the 2/3 come from - where do the medians intersect?
#
# Taking u as midpoint of x, we can express every point on median through C as : y + s(u - y) = y + s(1/2x - y)
#
# Similarly, for median through A, we write the median line as : 1/2t(x + y). Equating for intersection:
#
# 1/2t(x + y) = y + s(1/2x - y)
#
# Rewriting:
#
# t/2(x) + t/2(y) = s/2 (x) + (1 - s)(y)
#
# t = s, and s/2 = 1 -s => 3/2s = 1 or s = t = 2/3

# %% [markdown]
# **Homework (linear combination of 2 vectors is unique, if not parallel)**
#
# Prove: if u and v are two vectors, and not parallel to each other, then if :
#
# Au + Bv = Cu + Dv, then A = C and B = D
#
# Note that u and v not being parallel => u,v are not 0
#
# Rearranging, we get:
#
# (A - C)u = -(B - D)v
#
# If A ne C, then u and v are parallel contradicting the the hypothesis. But if A = C, then 0u = -(B-D)v, which is only possible if B = D, since v is not zero.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider

# 1. Define fixed triangle vertices in global coordinates
A = np.array([2.0, 6.0])
B = np.array([1.0, 1.0])
C = np.array([7.0, 2.0])  # <-- Correctly defined vertex C

# 2. Compute midpoints and global centroid
M_AB = (A + B) / 2
M_BC = (B + C) / 2
M_CA = (C + A) / 2
G = (A + B + C) / 3

def update_plot(origin_x, origin_y):
    # 3. Define movable origin vector
    O = np.array([origin_x, origin_y])
    
    # 4. Set up the plotting canvas
    fig, ax = plt.subplots(figsize=(9, 9))
    ax.set_xlim(-4, 9)
    ax.set_ylim(-4, 9)
    ax.axhline(0, color='black', linewidth=0.8, alpha=0.5)
    ax.axvline(0, color='black', linewidth=0.8, alpha=0.5)
    ax.grid(True, linestyle='--', alpha=0.5)
    
    # 5. Draw the Triangle Perimeter
    triangle_x = [A[0], B[0], C[0], A[0]]
    triangle_y = [A[1], B[1], C[1], A[1]]
    ax.plot(triangle_x, triangle_y, color='purple', linestyle='-', linewidth=2, label='Triangle Edge')
    
    # 6. Mark Vertices and Midpoints
    ax.scatter([A[0], B[0], C[0]], [A[1], B[1], C[1]], color='darkblue', s=80, zorder=5)
    ax.scatter([M_AB[0], M_BC[0], M_CA[0]], [M_AB[1], M_BC[1], M_CA[1]], color='teal', s=50, marker='s', zorder=5)
    ax.scatter(G[0], G[1], color='red', s=120, marker='*', label='Centroid (G)', zorder=6)
    ax.scatter(O[0], O[1], color='black', s=100, marker='x', label='Origin (O)', zorder=6)
    
    # Text labels for points
    ax.text(A[0]+0.1, A[1]+0.1, 'A', fontsize=12, fontweight='bold')
    ax.text(B[0]-0.2, B[1]-0.2, 'B', fontsize=12, fontweight='bold')
    ax.text(C[0]+0.1, C[1]-0.2, 'C', fontsize=12, fontweight='bold')
    ax.text(M_AB[0]-0.4, M_AB[1]+0.1, 'M_AB', fontsize=9, color='teal')
    ax.text(M_BC[0]+0.1, M_BC[1]-0.3, 'M_BC', fontsize=9, color='teal')
    ax.text(M_CA[0]+0.1, M_CA[1]+0.1, 'M_CA', fontsize=9, color='teal')
    
    # 7. Helper function to plot position vectors from origin
    def draw_vector(target, color, label):
        vector = target - O
        ax.quiver(O[0], O[1], vector[0], vector[1], 
                  angles='xy', scale_units='xy', scale=1, 
                  color=color, width=0.004, alpha=0.6, label=label)

    # 8. Plot position vectors
    draw_vector(A, 'blue', 'Vector OA')
    draw_vector(B, 'blue', 'Vector OB')
    draw_vector(C, 'blue', 'Vector OC')
    draw_vector(G, 'red', 'Centroid Vector OG')
    
    ax.set_title('Vector Centroid Demonstration with Movable Origin', fontsize=14, fontweight='bold')
    ax.legend(loc='upper right')
    plt.show()

# 9. Create interactive sliders for the origin position
interact(update_plot, 
         origin_x=FloatSlider(value=0.0, min=-3.0, max=5.0, step=0.5, description='Origin X:'),
         origin_y=FloatSlider(value=0.0, min=-3.0, max=5.0, step=0.5, description='Origin Y:'));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='Origin X:', max=5.0, min=-3.0, step=0.5), FloatSlide…
