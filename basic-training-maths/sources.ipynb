# %% [markdown]
# Basic Training in Mathematics - Ramamurthi Shankar

# %% [markdown]
# [Introduction to Integration - University of Sydney](https://www.sydney.edu.au/content/dam/students/documents/mathematics-learning-centre/integration-anti-derivative.pdf)

# %% [markdown]
# [Paul's Online Notes: Integration Techniques](https://tutorial.math.lamar.edu/classes/calcii/inttechintro.aspx)
